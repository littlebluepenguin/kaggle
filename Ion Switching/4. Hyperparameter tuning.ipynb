# %%
import pandas as pd
import numpy as np

from utils import reduce_mem_usage

train = pd.read_csv('../input/ion-switching-3-feature-engineering/train_features.csv')

X, y = train.drop(['open_channels', 'time'], axis=1), train['open_channels']

# %%
X = reduce_mem_usage(X)
# Out:
# Mem. usage decreased to 430.11 Mb (66.9% reduction)

# %%
import optuna

from sklearn.metrics import f1_score
from sklearn.model_selection import train_test_split

from lightgbm import LGBMClassifier

def objective(trial):
    '''
    optuna objective function
    '''
    
    n_estimators = trial.suggest_int('n_estimators', 10, 100)
    num_leaves = trial.suggest_int('num_leaves', 20, 300)
    learning_rate = trial.suggest_loguniform('learning_rate', 0.01, 0.2)
    reg_alpha = trial.suggest_loguniform('reg_alpha', 0.01, 5)
    reg_lambda = trial.suggest_loguniform('reg_lambda', 0.01, 5)
    max_depth = trial.suggest_int('max_depth', 8, 30)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=0.2)
    
    lgbm = LGBMClassifier(n_estimators=n_estimators,
                          learning_rate=learning_rate,
                          reg_alpha=reg_alpha,
                          reg_lambda=reg_lambda,
                          max_depth=max_depth,
                          num_leaves=num_leaves,
                          random_state=0)
    
    lgbm.fit(X_train, y_train)
    
    preds = lgbm.predict(X_test)
    
    score = f1_score(y_test, preds, average='macro')
    
    # to maximize the score minimize the negative of the score
    return -score

study = optuna.create_study()
study.optimize(objective, n_trials=20)

study.best_params
# Out:
# <style type='text/css'>
# .datatable table.frame { margin-bottom: 0; }
# .datatable table.frame thead { border-bottom: none; }
# .datatable table.frame tr.coltypes td {  color: #FFFFFF;  line-height: 6px;  padding: 0 0.5em;}
# .datatable .bool    { background: #DDDD99; }
# .datatable .object  { background: #565656; }
# .datatable .int     { background: #5D9E5D; }
# .datatable .float   { background: #4040CC; }
# .datatable .str     { background: #CC4040; }
# .datatable .row_index {  background: var(--jp-border-color3);  border-right: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  font-size: 9px;}
# .datatable .frame tr.coltypes .row_index {  background: var(--jp-border-color0);}
# .datatable th:nth-child(2) { padding-left: 12px; }
# .datatable .hellipsis {  color: var(--jp-cell-editor-border-color);}
# .datatable .vellipsis {  background: var(--jp-layout-color0);  color: var(--jp-cell-editor-border-color);}
# .datatable .na {  color: var(--jp-cell-editor-border-color);  font-size: 80%;}
# .datatable .footer { font-size: 9px; }
# .datatable .frame_dimensions {  background: var(--jp-border-color3);  border-top: 1px solid var(--jp-border-color0);  color: var(--jp-ui-font-color3);  display: inline-block;  opacity: 0.6;  padding: 1px 10px 1px 5px;}
# </style>
# [I 2021-01-27 12:56:40,186] A new study created in memory with name: no-name-60fe3ee4-7bf3-4100-ac06-1a093354b5ea
# [I 2021-01-27 13:01:44,228] Trial 0 finished with value: -0.9401391497842877 and parameters: {'n_estimators': 64, 'num_leaves': 229, 'learning_rate': 0.012942224027402692, 'reg_alpha': 0.015339206496057927, 'reg_lambda': 1.0224853815960262, 'max_depth': 14}. Best is trial 0 with value: -0.9401391497842877.
# [I 2021-01-27 13:07:05,097] Trial 1 finished with value: -0.9402459039195699 and parameters: {'n_estimators': 73, 'num_leaves': 93, 'learning_rate': 0.05011637258507193, 'reg_alpha': 0.05118227683177001, 'reg_lambda': 2.2550042799753784, 'max_depth': 14}. Best is trial 1 with value: -0.9402459039195699.
# [I 2021-01-27 13:09:18,802] Trial 2 finished with value: -0.939866442338878 and parameters: {'n_estimators': 27, 'num_leaves': 241, 'learning_rate': 0.02559130096983619, 'reg_alpha': 0.13625482789182514, 'reg_lambda': 0.04627837146442916, 'max_depth': 25}. Best is trial 1 with value: -0.9402459039195699.
# [I 2021-01-27 13:11:52,035] Trial 3 finished with value: -0.9391487286809714 and parameters: {'n_estimators': 37, 'num_leaves': 64, 'learning_rate': 0.01381253282835825, 'reg_alpha': 0.013591906194177075, 'reg_lambda': 0.021428304104018584, 'max_depth': 19}. Best is trial 1 with value: -0.9402459039195699.
# [I 2021-01-27 13:17:34,998] Trial 4 finished with value: -0.9399060105875123 and parameters: {'n_estimators': 74, 'num_leaves': 189, 'learning_rate': 0.015171454912620366, 'reg_alpha': 0.048583453612126445, 'reg_lambda': 0.0217285449147287, 'max_depth': 9}. Best is trial 1 with value: -0.9402459039195699.
# [I 2021-01-27 13:21:10,793] Trial 5 finished with value: -0.9403082853337575 and parameters: {'n_estimators': 50, 'num_leaves': 86, 'learning_rate': 0.05046168210580444, 'reg_alpha': 0.1813304097123241, 'reg_lambda': 0.5855195779584551, 'max_depth': 26}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:22:07,777] Trial 6 finished with value: -0.939758476451397 and parameters: {'n_estimators': 11, 'num_leaves': 215, 'learning_rate': 0.049215841863714235, 'reg_alpha': 4.88018506913276, 'reg_lambda': 0.06598519364279, 'max_depth': 12}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:23:13,474] Trial 7 finished with value: -0.9388478745634007 and parameters: {'n_estimators': 14, 'num_leaves': 25, 'learning_rate': 0.19055716516177265, 'reg_alpha': 0.4997382590564834, 'reg_lambda': 1.6269427207646687, 'max_depth': 18}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:30:32,976] Trial 8 finished with value: -0.9393382830037137 and parameters: {'n_estimators': 95, 'num_leaves': 288, 'learning_rate': 0.13633797902910494, 'reg_alpha': 0.010065456382495482, 'reg_lambda': 0.17781155545273603, 'max_depth': 14}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:35:19,350] Trial 9 finished with value: -0.9383597389346868 and parameters: {'n_estimators': 67, 'num_leaves': 176, 'learning_rate': 0.1898513640417014, 'reg_alpha': 0.012103327907412432, 'reg_lambda': 0.8238694104892584, 'max_depth': 9}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:38:29,528] Trial 10 finished with value: -0.9401176800750378 and parameters: {'n_estimators': 44, 'num_leaves': 110, 'learning_rate': 0.08682646278121187, 'reg_alpha': 1.0289891057957297, 'reg_lambda': 0.3623177635653242, 'max_depth': 30}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:44:41,113] Trial 11 finished with value: -0.9400014120586271 and parameters: {'n_estimators': 86, 'num_leaves': 113, 'learning_rate': 0.04647601448180617, 'reg_alpha': 0.08400317897441496, 'reg_lambda': 2.831217109762506, 'max_depth': 26}. Best is trial 5 with value: -0.9403082853337575.
# [I 2021-01-27 13:48:36,416] Trial 12 finished with value: -0.9405386455613791 and parameters: {'n_estimators': 55, 'num_leaves': 109, 'learning_rate': 0.07017221936117332, 'reg_alpha': 0.3704152498175369, 'reg_lambda': 4.635072378973831, 'max_depth': 22}. Best is trial 12 with value: -0.9405386455613791.
# [I 2021-01-27 13:51:38,670] Trial 13 finished with value: -0.9402551184901778 and parameters: {'n_estimators': 50, 'num_leaves': 23, 'learning_rate': 0.08719782538047101, 'reg_alpha': 0.3715539768210344, 'reg_lambda': 4.718813532830648, 'max_depth': 24}. Best is trial 12 with value: -0.9405386455613791.
# [I 2021-01-27 13:55:39,363] Trial 14 finished with value: -0.9405887019112084 and parameters: {'n_estimators': 56, 'num_leaves': 135, 'learning_rate': 0.0291531383248232, 'reg_alpha': 1.4994012659353708, 'reg_lambda': 0.3805273375983891, 'max_depth': 30}. Best is trial 14 with value: -0.9405887019112084.
# [I 2021-01-27 13:57:49,514] Trial 15 finished with value: -0.9400433266327218 and parameters: {'n_estimators': 30, 'num_leaves': 143, 'learning_rate': 0.029017969741825723, 'reg_alpha': 2.1082009273883053, 'reg_lambda': 0.1415179471820504, 'max_depth': 29}. Best is trial 14 with value: -0.9405887019112084.
# [I 2021-01-27 14:01:52,370] Trial 16 finished with value: -0.9401880153399588 and parameters: {'n_estimators': 59, 'num_leaves': 140, 'learning_rate': 0.027488691591415614, 'reg_alpha': 1.5598461484910646, 'reg_lambda': 4.915096117431169, 'max_depth': 21}. Best is trial 14 with value: -0.9405887019112084.
# [I 2021-01-27 14:07:20,697] Trial 17 finished with value: -0.9401148776210158 and parameters: {'n_estimators': 82, 'num_leaves': 58, 'learning_rate': 0.08720100380727092, 'reg_alpha': 4.221583090422288, 'reg_lambda': 0.3407542903951879, 'max_depth': 22}. Best is trial 14 with value: -0.9405887019112084.
# [I 2021-01-27 14:11:05,449] Trial 18 finished with value: -0.93988155186744 and parameters: {'n_estimators': 54, 'num_leaves': 118, 'learning_rate': 0.019153712480597405, 'reg_alpha': 0.7323942899677519, 'reg_lambda': 0.012009750974032646, 'max_depth': 28}. Best is trial 14 with value: -0.9405887019112084.
# [I 2021-01-27 14:14:02,406] Trial 19 finished with value: -0.9403851131719516 and parameters: {'n_estimators': 40, 'num_leaves': 158, 'learning_rate': 0.07137632367178888, 'reg_alpha': 2.6773856193928447, 'reg_lambda': 0.09148533425640908, 'max_depth': 18}. Best is trial 14 with value: -0.9405887019112084.
# {'n_estimators': 56,
#  'num_leaves': 135,
#  'learning_rate': 0.0291531383248232,
#  'reg_alpha': 1.4994012659353708,
#  'reg_lambda': 0.3805273375983891,
#  'max_depth': 30}
